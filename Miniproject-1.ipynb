# %%
from ultralytics import YOLO
model=YOLO('YOLO26n.pt')
result=model.train(data='cv_miniproject_1/data.yaml',epochs=50,imgsz=640,patience=15)
# Out:
# New https://pypi.org/project/ultralytics/8.4.63 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.62  Python-3.13.5 torch-2.12.0+cpu CPU (Intel Core Ultra 5 125H)
# ...

# %%
model_final=YOLO('runs/detect/train-2/weights/best.pt')
results=model_final('cv_miniproject_1/test/images/trial1.jpg', save=True)
results[0].show()
# Out:
# image 1/1 C:\Users\Priyanshu Bansal\computer vision\cv_miniproject_1\test\images\trial8.jpg: 640x640 1 Table, 1 chair, 163.0ms
# Speed: 7.5ms preprocess, 163.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\Priyanshu Bansal\computer vision\runs\detect\predict-15
